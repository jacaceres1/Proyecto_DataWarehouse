# %% [markdown]
# librery import

# %%
import pandas as pd
import sqlite3 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
from sqlalchemy import inspect
from sqlalchemy import MetaData
import sqlite3
import datetime

# %% [markdown]
# Extract

# %%
con = sqlite3.connect("Northwind_large.sqlite")
cursorObj = con.cursor()

# %% [markdown]
# TRANSFORM

# %%
df_custom = pd.read_sql_query(
    """
   SELECT Id AS Id_customer,
       CompanyName,
       ContactName,
       ContactTitle,
       Address,
       City,
       Region,
       ifnull(PostalCode,'No Asignado') as PostalCode,
       replace(replace(Country,"UK","United Kingdom"),"USA","The United States of America")  as Country,
       Phone,
       ifnull(Fax,'No asignado') as Fax
FROM Customer;
    """
    ,con)
df_custom.head(5)
# Out:
#   Id_customer                         CompanyName         ContactName  \
# 0       ALFKI                 Alfreds Futterkiste        Maria Anders
# 1       ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2       ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3       AROUT                     Around the Horn        Thomas Hardy
# 4       BERGS                  Berglunds snabbköp  Christina Berglund
#
#            ContactTitle                        Address         City  \
# 0  Sales Representative                  Obere Str. 57       Berlin
# 1                 Owner  Avda. de la Constitución 2222  México D.F.
# 2                 Owner                Mataderos  2312  México D.F.
# 3  Sales Representative                120 Hanover Sq.       London
# 4   Order Administrator                Berguvsvägen  8        Luleå
#
#             Region PostalCode         Country           Phone             Fax
# 0   Western Europe      12209         Germany     030-0074321     030-0076545
# 1  Central America      05021          Mexico    (5) 555-4729    (5) 555-3745
# 2  Central America      05023          Mexico    (5) 555-3932     No asignado
# 3    British Isles    WA1 1DP  United Kingdom  (171) 555-7788  (171) 555-6750
# 4  Northern Europe   S-958 22          Sweden   0921-12 34 65   0921-12 34 67

# %%
df_employee = pd.read_sql_query(
    """
SELECT e.Id AS Id_employe,
       e.Lastname,
       e.FirstName,
       e.Title,
       replace(replace(replace(replace(e.TitleOfCourtesy,"Dr","Doctor"),"Ms","Lady"),"Mr","Mister"),"Mrs"," Missus") as TitleOfCourtesy,
       e.BirthDate,
       e.HireDate,
       e.Address,
       e.City,
       e.Region,
       e.PostalCode,
       replace(replace(e.Country,"UK","United Kingdom"),"USA","The United States of America") as Country,
       e.HomePhone,
       e.Extension,
       ifnull(e.Photo,'No Asignado') as Photo,
       e.Notes,
       e.PhotoPath
FROM employee AS e;
    """
    ,con)
df_employee.head(5)
# Out:
#    Id_employe   LastName FirstName                  Title TitleOfCourtesy  \
# 0           1    Davolio     Nancy   Sales Representative           Lady.
# 1           2     Fuller    Andrew  Vice President, Sales         Doctor.
# 2           3  Leverling     Janet   Sales Representative           Lady.
# 3           4    Peacock  Margaret   Sales Representative        Misters.
# 4           5   Buchanan    Steven          Sales Manager         Mister.
#
#     BirthDate    HireDate                     Address      City  \
# 0  1980-12-08  2024-05-01  507 - 20th Ave. E. Apt. 2A   Seattle
# 1  1984-02-19  2024-08-14          908 W. Capital Way    Tacoma
# 2  1995-08-30  2024-04-01          722 Moss Bay Blvd.  Kirkland
# 3  1969-09-19  2025-05-03        4110 Old Redmond Rd.   Redmond
# 4  1987-03-04  2025-10-17             14 Garrett Hill    London
#
#           Region PostalCode                       Country       HomePhone  \
# 0  North America      98122  The United States of America  (206) 555-9857
# 1  North America      98401  The United States of America  (206) 555-9482
# 2  North America      98033  The United States of America  (206) 555-3412
# 3  North America      98052  The United States of America  (206) 555-8122
# 4  British Isles    SW1 8JR                United Kingdom   (71) 555-4848
#
#   Extension        Photo                                              Notes  \
# 0      5467  No Asignado  Education includes a BA in psychology from Col...
# 1      3457  No Asignado  Andrew received his BTS commercial in 1974 and...
# 2      3355  No Asignado  Janet has a BS degree in chemistry from Boston...
# 3      5176  No Asignado  Margaret holds a BA in English literature from...
# 4      3453  No Asignado  Steven Buchanan graduated from St. Andrews Uni...
#
#                                 PhotoPath
# 0    http://accweb/emmployees/davolio.bmp
# 1     http://accweb/emmployees/fuller.bmp
# 2  http://accweb/emmployees/leverling.bmp
# 3    http://accweb/emmployees/peacock.bmp
# 4   http://accweb/emmployees/buchanan.bmp

# %%
df_location = pd.read_sql_query(
    """
SELECT [order].Id AS Id_location,
                [order].ShipAddress AS Address,
                [order].ShipCity AS City,
                [order].ShipRegion  AS Region,
                ifnull([order].ShipPostalCode, 'No Asignado') AS PostalCode,
                [replace]([replace]([order].ShipCountry, "UK", "Unit Kingdom"), "USA", "The United States of America") AS Country
  FROM [order];
    """
    ,con)
df_location.head(5)
# Out:
#    Id_location               Address            City          Region  \
# 0        10248    59 rue de l'Abbaye           Reims  Western Europe
# 1        10249         Luisenstr. 48         Münster  Western Europe
# 2        10250       Rua do Paço, 67  Rio de Janeiro   South America
# 3        10251    2, rue du Commerce            Lyon  Western Europe
# 4        10252  Boulevard Tirou, 255       Charleroi  Western Europe
#
#   PostalCode  Country
# 0      51100   France
# 1      44087  Germany
# 2  05454-876   Brazil
# 3      69004   France
# 4     B-6000  Belgium

# %%
df_product = pd.read_sql_query(
    """
SELECT Product.Id AS Id_product,
       ProductName,
       category.CategoryName,
       supplier.CompanyName as CompanyName_Supplier,
       product.QuantityPerUnit,
       product.UnitPrice,
       product.UnitsInStock,
       product.UnitsOnOrder,
       product.ReorderLevel,
       product.Discontinued
  FROM product
       INNER JOIN
       category ON product.CategoryId = category.Id
       INNER JOIN
       supplier ON product.SupplierId = supplier.Id;

    """
    ,con)
df_product.head(5)
# Out:
#    Id_product                   ProductName CategoryName  \
# 0           1                          Chai    Beverages
# 1           2                         Chang    Beverages
# 2           3                 Aniseed Syrup   Condiments
# 3           4  Chef Anton's Cajun Seasoning   Condiments
# 4           5        Chef Anton's Gumbo Mix   Condiments
#
#          CompanyName_Supplier      QuantityPerUnit  UnitPrice  UnitsInStock  \
# 0              Exotic Liquids   10 boxes x 20 bags      18.00            39
# 1              Exotic Liquids   24 - 12 oz bottles      19.00            17
# 2              Exotic Liquids  12 - 550 ml bottles      10.00            13
# 3  New Orleans Cajun Delights       48 - 6 oz jars      22.00            53
# 4  New Orleans Cajun Delights             36 boxes      21.35             0
#
#    UnitsOnOrder  ReorderLevel  Discontinued
# 0             0            10             0
# 1            40            25             0
# 2            70            25             0
# 3             0             0             0
# 4             0             0             1

# %%
df_shipper = pd.read_sql_query(
    """

SELECT Id AS Id_shipper,
       CompanyName,
       Phone
  FROM shipper;
    """
    ,con)
df_shipper.head(5)
# Out:
#    Id_shipper       CompanyName           Phone
# 0           1    Speedy Express  (503) 555-9831
# 1           2    United Package  (503) 555-3199
# 2           3  Federal Shipping  (503) 555-9931

# %%
df_time = pd.read_sql_query(
    """
SELECT distinct
    strftime('%Y%m%d',[order].ShippedDate ) AS TimeId,
    [order].ShippedDate as fecha,
        strftime('%Y', [order].ShippedDate) AS año,
       strftime('%m', [order].ShippedDate) AS mes,
       strftime('%d', [order].ShippedDate) AS dia,
       case strftime('%w',[order].ShippedDate)
         when '0' then 'Domingo'
         when '1' then 'Lunes'
         when '2' then 'Martes'
         when '3' then 'Miercoles'
         when '4' then 'Jueves'
         when '5' then 'Viernes'
         when '6' then 'Sabado'
       end as nombre_dia,
       strftime('%w', [order].ShippedDate) as dia_semana,
       strftime('%W', [order].ShippedDate) AS semana,
       case 
        when 0 + strftime('%m', [order].ShippedDate) between  1 and  4 then 'Primer Trimestre'
        when 0 + strftime('%m', [order].ShippedDate) between  5 and  8 then 'Segundo Trimestre'
        when 0 + strftime('%m', [order].ShippedDate) between  9 and  12 then 'Tercer Trimestre'
    end as trimestre     
FROM [order] 
where TimeId IS NOT NULL
group by TimeId;
    """
    ,con)
df_time.head(5)
# Out:
#      TimeId                fecha   año mes dia nombre_dia dia_semana semana  \
# 0  20120710           2012-07-10  2012  07  10     Martes          2     28
# 1  20120711           2012-07-11  2012  07  11  Miercoles          3     28
# 2  20120712           2012-07-12  2012  07  12     Jueves          4     28
# 3  20120713  2012-07-13 22:19:41  2012  07  13    Viernes          5     28
# 4  20120715           2012-07-15  2012  07  15    Domingo          0     28
#
#            trimestre
# 0  Segundo Trimestre
# 1  Segundo Trimestre
# 2  Segundo Trimestre
# 3  Segundo Trimestre
# 4  Segundo Trimestre

# %%
df_fact = pd.read_sql_query(
    """
SELECT DISTINCT OrderDetail.Id AS Id_fact,
       [order].CustomerId AS id_customer,
       [order].ShipVia AS id_shipper,
       strftime('%Y%m%d', [order].ShippedDate) AS id_time,
       OrderDetail.ProductId as id_product,
       [order].Id as Id_location,
       employee.Id as Id_employe,
       [order].Freight,
       OrderDetail.UnitPrice,
       OrderDetail.Quantity,
       OrderDetail.Discount,
       round((((OrderDetail.UnitPrice*OrderDetail.Quantity) * (1-OrderDetail.Discount))/1)+[order].Freight,1) as finalprice
  FROM [order]
  inner join OrderDetail on [order].Id = OrderDetail.OrderId
  inner join employee on [order].EmployeeId = employee.Id;
    """
    ,con)
df_fact.head(5)
# Out:
#     Id_fact id_customer  id_shipper   id_time  id_product  Id_location  \
# 0  10248/11       VINET           3  20120716          11        10248
# 1  10248/42       VINET           3  20120716          42        10248
# 2  10248/72       VINET           3  20120716          72        10248
# 3  10249/14       TOMSP           1  20120710          14        10249
# 4  10249/51       TOMSP           1  20120710          51        10249
#
#    Id_employe  Freight  UnitPrice  Quantity  Discount  finalprice
# 0           5    16.75       14.0        12       0.0       184.8
# 1           5    16.75        9.8        10       0.0       114.8
# 2           5    16.75       34.8         5       0.0       190.8
# 3           6    22.25       18.6         9       0.0       189.7
# 4           6    22.25       42.4        40       0.0      1718.3

# %% [markdown]
# LOAD

# %%
con2 = sqlite3.connect("DW_NORTH.db")
con2

# %% [markdown]
# CARGA DE CLIENTE

# %%
df_custom.to_sql('dim_customer', con2, if_exists='append',index=False)
# Out:
# 91

# %% [markdown]
# CARGA DE EMPLEADO

# %%
df_employee.to_sql('dim_employee', con2, if_exists='append',index=False)
# Out:
# 9

# %% [markdown]
# CARGA LOCATION

# %%
df_location.to_sql('dim_location',con2,if_exists='append',index=False)
# Out:
# 16818

# %% [markdown]
# CARGA PRODCUTO

# %%
df_product.to_sql('dim_product',con2,if_exists='append',index=False)
# Out:
# 77

# %% [markdown]
# CARGA SHIPPER

# %%
df_shipper.to_sql('dim_shipper',con2,if_exists='append',index=False)
# Out:
# 3

# %% [markdown]
# CARGA TIEMPO

# %%
df_time.to_sql('dim_Time',con2,if_exists='append',index=False)
# Out:
# 1339

# %% [markdown]
# CARGA FACTURAS

# %%
df_fact.to_sql('fact_sales',con2,if_exists='append',index=False)
# Out:
# 621883

# %% [markdown]
# Datos

# %%
df_fact.to_csv("prueba.csv")

# %%
df_product.to_csv("productos.csv", index=False)
